# %% [markdown]
# ## SVM Implementation with Stochastic Gradient Descent

# %%
import numpy as np
import matplotlib.pyplot as plt #only used for plotting!!!
# %matplotlib inline

from sklearn.datasets import make_blobs #only imported .dataset to generate the dataset, package is not used for anything else!!!

# %%
## generate data points
N = 200  # number of samples
D = 2  # number of dimensions
C = 2  # number of classes
seed = 12  # for reproducible experiments
cluster_std = 1.3
punish_const = 0.1

alpha_tol = 1e-4 # threshold for choosing support vectors

X, y = make_blobs(n_samples=N, n_features=D, centers=C, random_state=seed, cluster_std = cluster_std)
y[y == 0] = -1  # it is more convenient to have {-1, 1} as class labels (instead of {0, 1})
y = y.astype(np.float)
plt.figure(figsize=[10, 8])
plt.scatter(X[:,0], X[:, 1], c=y)
plt.show()

# %%
from svms import sgd_SVM

if __name__ == "__main__":
    def generate_data(N, D, C, seed):
        X, y = make_blobs(n_samples=N, n_features=D, centers=C, random_state=seed, cluster_std=cluster_std)
        y[y == 0] = -1  
        return X, y.astype(np.float)

    def plot_svm_sgd(X, y, w, b):
        plt.figure(figsize=[10, 8])
        # Plot the hyperplane
        slope = -w[0] / w[1]
        intercept = -b / w[1]
        x = np.linspace(X[:, 0].min(), X[:, 0].max())
        plt.plot(x, x * slope + intercept, 'k-', label='decision boundary')
        plt.plot(x, x * slope + intercept - 1/w[1], 'k--')
        plt.plot(x, x * slope + intercept + 1/w[1], 'k--')
        # Plot all the datapoints
        plt.scatter(X[:, 0], X[:, 1], c=y)
        plt.xlabel('$x_1$')
        plt.ylabel('$x_2$')
        plt.legend(loc='upper left')

    def run_svm_sgd():
        sampels, labels = generate_data(N, D, C, seed)

        svm_sgd = sgd_SVM()
        #w, b = svm_sgd.fit(sampels ,labels, batch_size=32, lr=0.001, iterations=3000)
        w, b = svm_sgd.fit(sampels ,labels, batch_size=32, iterations=3000)
        plot_svm_sgd(X, y, w, b)

# %%
run_svm_sgd()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-50-8949b3ad21c6> in <module>
# ----> 1 run_svm_sgd()
#
# <ipython-input-49-e7a9d495307c> in run_svm_sgd()
#      27         svm_sgd = sgd_SVM()
#      28         #w, b = svm_sgd.fit(sampels ,labels, batch_size=32, lr=0.001, iterations=3000)
# ---> 29         w, b = svm_sgd.fit(sampels ,labels, batch_size=32, iterations=3000)
#      30         plot_svm_sgd(X, y, w, b)
#
# ~/Dropbox/uni/master/semester4/M4ML/project2/M4ML2/project3/svms.py in fit(self, X, y, batch_size, learning_rate, iterations)
#     130
#     131     def fit(self, X, y, batch_size=96, lr=0.001, iterations=5000):
# --> 132         #get number of samples, number of features and regularization parameter C
#     133         N, D = X.shape
#     134         C = self.C
#
# AttributeError: 'sgd_SVM' object has no attribute 'C'

# %%
from svms import gd_SVM
sampels, labels = generate_data(N, D, C, seed)

svm_gd = gd_SVM()
w, b = svm_gd.fit(sampels ,labels, batch_size=32, lr=0.001, iterations=3000)
plot_svm_sgd(X,y,w,b)
print(w,b)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-45-22735f651b00> in <module>
# ----> 1 from svms import gd_SVM
#       2 sampels, labels = generate_data(N, D, C, seed)
#       3
#       4 svm_gd = gd_SVM()
#       5 w, b = svm_gd.fit(sampels ,labels, batch_size=32, lr=0.001, iterations=3000)
#
# ImportError: cannot import name 'gd_SVM' from 'svms' (/Users/timmaier/Dropbox/uni/master/semester4/M4ML/project2/M4ML2/project3/svms.py)
